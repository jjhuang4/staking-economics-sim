# %%
import os
import sys

# 1. Check if the Repo is actually in the Python Path
expected_path = "/workspace/cadlabs-model"
if expected_path in sys.path:
    print(f"✅ PYTHONPATH is correct: {expected_path}")
else:
    print(f"❌ PYTHONPATH missing! Current path: {sys.path}")
# Out:
# ✅ PYTHONPATH is correct: /workspace/cadlabs-model

# %%
# !ls -a /workspace/
# Out:
# .  ..  cadlabs-model  shared

# %%
# !ls -a /workspace/cadlabs-model/
# !ls -a /workspace/cadlabs-model/.api.cache
# Out:
# .		     .gitignore      ROADMAP.md		      model
# ..		     .pylintrc	     build_docs.py	      notebooks
# .all-contributorsrc  ASSUMPTIONS.md  data		      pytest.ini
# .api.cache	     CHANGELOG.md    docs		      requirements.txt
# .git		     LICENSE	     environment_setup.ipynb  runtime.txt
# .gitattributes	     Makefile	     experiments	      tests
# .github		     README.md	     logs
# .  ..  cache.db  cache.db-shm  cache.db-wal
