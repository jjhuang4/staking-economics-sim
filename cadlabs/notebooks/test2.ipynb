# %%
import os, sys, dotenv, json

os.chdir('/workspace/cadlabs-model/experiments/notebooks')
assert os.getcwd() == '/workspace/cadlabs-model/experiments/notebooks', "Incorrect current working directory"

# %% [markdown]
# At this point the environment should be pointing to /workspace/cadlabs-model
# Set the current working directory to /cadlabs-model/experiments/notebooks to develop notebooks
#
# The setup file that is inside the notebooks folder is using a deprecated version/command from ipython, so we make our own here.

# %%
print(json.dumps(os.listdir('.'), indent=4))
# Out:
# [
#     "3_network_issuance_and_inflation_rate.ipynb",
#     "1_model_validation.ipynb",
#     "template.ipynb",
#     "2_validator_revenue_and_profit_yields.ipynb",
#     "simulation_profiling",
#     "0_README.ipynb",
#     "visualizations",
#     "setup.py"
# ]

# %%
import setup
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 import setup
#
# File /workspace/cadlabs-model/experiments/notebooks/setup.py:13
#       6 ipython = get_ipython()
#       8 # Find performance bottlenecks by timing Python cell execution
#       9 # ipython.magic("load_ext autotime") # ipython.magic("...") is equivalent to % in Jupyter cell
#      10
#      11 # Reload all modules (except those excluded by %aimport) every time before executing the Python code typed
#      12 # See https://ipython.org/ipython-doc/stable/config/extensions/autoreload.html
# ---> 13 ipython.magic("load_ext autoreload")
#      14 ipython.magic("autoreload 2")
#      16 # Append the root directory to Python path,
#      17 # this allows you to store notebooks in `experiments/notebooks/` sub-directory and access model Python modules
#
# ...

# %%
# import setup

import copy
import logging
import numpy as np
from radcad import Engine

import experiments.notebooks.visualizations as visualizations
from experiments.run import run
from model.types import Stage
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 import setup
#       3 import copy
#       4 import logging
#
# File /workspace/cadlabs-model/experiments/notebooks/setup.py:13
#       6 ipython = get_ipython()
#       8 # Find performance bottlenecks by timing Python cell execution
#       9 # ipython.magic("load_ext autotime") # ipython.magic("...") is equivalent to % in Jupyter cell
#      10
#      11 # Reload all modules (except those excluded by %aimport) every time before executing the Python code typed
#      12 # See https://ipython.org/ipython-doc/stable/config/extensions/autoreload.html
# ---> 13 ipython.magic("load_ext autoreload")
#      14 ipython.magic("autoreload 2")
#      16 # Append the root directory to Python path,
# ...

# %%
e
